# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sec_a = np.array([75,65,73,68,72,76])
sec_b = np.array([90,47,43,96,93,51])
no = np.array([1,2,3,4,5,6])

# %%
np.std(sec_a), np.std(sec_b)
# Out:
# (np.float64(3.8622100754188224), np.float64(23.18045153428495))

# %%
np.var(sec_a), np.var(sec_b)
# Out:
# (np.float64(14.916666666666666), np.float64(537.3333333333334))

# %%
dataset = pd.read_csv("titanic_sample_1000.csv")
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Fare Embarked
# 0            1         1       2    male  21.0      0      0  40.82        S
# 1            2         0       3    male  17.0      1      0  10.52        S
# 2            3         0       3  female  23.0      1      0  12.33        S

# %%
dataset["Age"].var()
# Out:
# np.float64(137.24456194967115)

# %% [markdown]
# The above data is fully spreaded

# %%
sns.histplot(x="Age",data=dataset)
plt.show()

# %%
dataset["Age"].std()
# Out:
# np.float64(11.715142421228654)

# %%
dataset.describe()
# Out:
#        PassengerId     Survived      Pclass         Age        SibSp  \
# count  1000.000000  1000.000000  1000.00000  810.000000  1000.000000
# mean    500.500000     0.302000     2.28400   29.186420     0.438000
# std     288.819436     0.459355     0.84502   11.715142     0.805484
# min       1.000000     0.000000     1.00000    1.000000     0.000000
# 25%     250.750000     0.000000     1.00000   21.000000     0.000000
# 50%     500.500000     0.000000     3.00000   29.000000     0.000000
# 75%     750.250000     1.000000     3.00000   37.000000     1.000000
# max    1000.000000     1.000000     3.00000   66.000000     4.000000
#
#             Parch         Fare
# count  1000.00000  1000.000000
# mean      0.36000    39.147900
# std       0.73276    49.681657
# min       0.00000     4.530000
# 25%       0.00000    10.397500
# 50%       0.00000    17.385000
# 75%       0.00000    47.207500
# max       3.00000   512.330000
