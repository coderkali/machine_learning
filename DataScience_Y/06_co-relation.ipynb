# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("tips.csv")

# %%
dataset.head(3)
# Out:
#    total_bill   tip   sex smoker   day    time  size
# 0       16.74  2.68  Male     No   Fri  Dinner     2
# 1       13.09  1.18  Male     No  Thur  Dinner     4
# 2       39.30  6.45  Male    Yes   Sun  Dinner     4

# %%
dataset.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  1000 non-null   float64
#  1   tip         1000 non-null   float64
#  2   sex         1000 non-null   str
#  3   smoker      1000 non-null   str
#  4   day         1000 non-null   str
#  5   time        1000 non-null   str
#  6   size        1000 non-null   int64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 54.8 KB

# %%
dataset.select_dtypes(["float64","int64"])
# Out:
#      total_bill   tip  size
# 0         16.74  2.68     2
# 1         13.09  1.18     4
# 2         39.30  6.45     4
# 3         26.77  5.58     2
# 4         20.42  2.34     2
# ..          ...   ...   ...
# 995       47.60  7.78     4
# 996       23.37  3.64     2
# 997       15.88  1.61     2
# 998       41.74  5.87     4
# 999       29.69  6.04     3
#
# [1000 rows x 3 columns]

# %%
data_cov = dataset.select_dtypes(["float64","int64"]).cov()
data_cov
# Out:
#             total_bill        tip      size
# total_bill  130.715213  22.401125  9.457814
# tip          22.401125   5.348316  1.635687
# size          9.457814   1.635687  1.178089

# %%
data_corr= dataset.select_dtypes(["float64","int64"]).corr()
data_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.847224  0.762147
# tip           0.847224  1.000000  0.651632
# size          0.762147  0.651632  1.000000

# %%
plt.figure(figsize=(4,3))
sns.heatmap(data_corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.heatmap(data_cov,annot=True)
plt.show()
